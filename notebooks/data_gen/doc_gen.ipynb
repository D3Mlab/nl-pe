# %%
import os
import yaml
import sys
from pathlib import Path
import csv
import json 
PROJECT_ROOT = Path.cwd().parent.parent  # points to nl-pe/
SRC_PATH = PROJECT_ROOT / "src"
sys.path.insert(0, str(SRC_PATH))  # make nl_pe importable
os.chdir(PROJECT_ROOT)  

from dotenv import load_dotenv
from nl_pe.llm import LLM_CLASSES
from nl_pe.llm.prompter import Prompter

# %%
CONFIG_PATH = "configs/llm/config.yaml"
with open(CONFIG_PATH, "r") as f:
    config = yaml.safe_load(f)


load_dotenv()
prompter = Prompter(config)

# %%
# Prompt with the template

template_path = 'hotel_gen.jinja2'
response = prompter.prompt_from_temp(template_path)

print("Full response:", response)
# Out:
# 2025-09-25 15:10:05,481 - OpenAILLM - DEBUG - calling llm api
# 2025-09-25 15:13:56,955 - OpenAILLM - DEBUG - Successfully parsed LLM response as JSON object
# Full response: {'message': '{\n  "doc_1": "Tucked along Kyoto’s lantern-lit lanes in Gion, this intimate ryokan blends centuries-old elegance with modern comfort. Tatami rooms open to mossy courtyards, and kaiseki dinners celebrate seasonal Kyoto produce. Guests unwind in cedar soaking tubs after tea ceremonies led by a local master. Steps from Yasaka Shrine and the Kamo River, the inn offers loaner kimono and discreet concierge service. Quiet, contemplative, and exquisitely detailed, it’s ideal for slow travelers who value craft, ritual, and the calming rhythm of temple bells drifting through the night.",\n  "doc_2": "On a private Maldivian atoll, this ultraluxe resort floats above a lagoon of electric-blue water. Overwater villas feature glass floor panels, plunge pools, and direct reef access for dawn snorkeling. A marine biologist leads manta safaris, while the spa’s sea-salt rituals soothe sun-kissed skin. Farm-to-table dining spotlights line-caught tuna and tropical fruit. Secluded yet meticulously serviced, the resort’s barefoot ethos encourages unplugging—think beach cinema under the stars and stargazing with an astronomer. It’s a castaway fantasy made seamless by butlers and whisper-soft, tide-timed tranquility.",\n  "doc_3": "In New York’s Midtown, this polished business hotel balances efficiency with understated style. Steps from Grand Central, it offers lightning-fast Wi-Fi, ergonomic workstations, and soundproof rooms for deep sleep after marathon meetings. A club lounge provides espresso, quiet corners, and skyline views, while the 24-hour gym caters to jet-lagged workouts. The restaurant prioritizes power breakfasts and seasonal menus. Attentive concierges secure hard-to-get tables and theater seats. With smart conference spaces and swift check-in, it’s a streamlined base for dealmakers who still appreciate a warm, human touch.",\n  "doc_4": "Carved into Cappadocia’s honeycomb cliffs, this boutique cave hotel turns ancient tuff rock into cocoon-like suites. Each chamber blends woven kilims and carved niches with heated stone floors and rain showers. Panoramic terraces overlook hot air balloons at sunrise, and a fireplace lounge pours local wines at dusk. The chef prepares Anatolian dishes baked in clay. Guided valley hikes and pottery workshops reveal regional craftsmanship. Quiet, otherworldly, and deeply atmospheric, it’s a soulful retreat that lets you sleep within the landscape itself, without sacrificing comfort.",\n  "doc_5": "On Rio de Janeiro’s Ipanema beachfront, this art-forward hotel thrums with carioca energy. Rooms frame the sea’s shifting blues, while a rooftop infinity pool watches surfers and sunset crowds. A resident DJ sets breezy rhythms; the lobby gallery showcases Brazilian designers and photographers. Freshly squeezed acerola juice fuels morning runs along the calçadão. With bicycles, beach attendants, and a samba concierge linking guests to nightlife, the vibe is playful yet polished. It’s a spirited, style-conscious base for beach lovers and urban explorers alike.",\n  "doc_6": "High in Peru’s Sacred Valley, this Andean lodge neighbors terraced fields and whispering eucalyptus. Adobe casitas feature alpaca blankets, wood stoves, and mountain-facing windows that flood rooms with golden light. A small spa offers coca-leaf massages; the kitchen sizzles with trout, quinoa, and garden herbs. Guided hikes connect villages and Inca sites, while stargazing reveals crystalline skies. Solar panels and community partnerships underscore a gentle footprint. Peaceful, grounded, and rich with local texture, it suits hikers and culture seekers acclimating before Machu Picchu.",\n  "doc_7": "In Cape Town’s revived Woodstock district, this converted warehouse pairs industrial bones with bright South African design. Polished concrete meets botanical murals; rooms feature craft furniture, rainfall showers, and Table Mountain glimpses. A rooftop plunge pool and braai nights anchor a convivial scene, while the ...

# %%
import json
import csv
from pathlib import Path

# Assuming `response` is the JSON response you received
if 'JSON_dict' in response:
    json_data = response['JSON_dict']

    # Extract docs from doc_1, doc_2, ... format
    doc_list = []
    i = 1
    while True:
        doc_key = f'doc_{i}'
        if doc_key in json_data:
            doc_list.append(json_data[doc_key])
            i += 1
        else:
            break

    print(f"Successfully parsed JSON with {len(doc_list)} documents in doc_1-doc_{i-1} format")

    # Save to CSV
    output_dir = Path('data/gen_docs')
    output_dir.mkdir(parents=True, exist_ok=True)

    csv_path = output_dir / 'hotels_1.csv'
    with open(csv_path, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['d_id', 'd_text'])
        for idx, doc_text in enumerate(doc_list, 1):
            writer.writerow([idx, doc_text])

    print(f"CSV file created successfully: {csv_path}")
else:
    print("No JSON_dict found in response")
# Out:
# Successfully parsed JSON with 100 documents in doc_1-doc_100 format
# CSV file created successfully: data\gen_docs\hotels_1.csv
