# %% [markdown]
# # KNN runtimes

# %% [markdown]
# ## toy city, qwen 600m, k = 10

# %%
#ONLY RUN THIS BLOCK ONCE!

import os
import sys
from pathlib import Path
from importlib import reload

PROJECT_ROOT = Path.cwd().parent.parent  # points to nl-pe/
SRC_PATH = PROJECT_ROOT / "src"
sys.path.insert(0, str(SRC_PATH))  # make nl_pe importable
os.chdir(PROJECT_ROOT)

# %%
import nl_pe.ploting.times as times_plot
reload(times_plot)
from nl_pe.ploting.times import plot_knn_times_scatter, plot_knn_times_boxplot

# %%
# Example usage
method_paths = [
    'trials/ir/toy_cities/single_tensor',
    'trials/ir/toy_cities/faiss',
    'trials/ir/toy_cities/shelve',
]

method_names = [
    'Single Tensor',
    'Faiss',
    'Shelve',
]

styles = [
    {'color': 'blue'},
    {'color': 'orange'},
    {'color': 'green'},
]

plot_knn_times_boxplot(method_paths, method_names, styles=styles,
                     title="Toy City (10 doc) Corpus Embedding Time per Method")
# Out:
# Loading KNN times for boxplot...
