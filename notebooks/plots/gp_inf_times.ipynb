# %%
#ONLY RUN THIS BLOCK ONCE!

import os
import sys
from pathlib import Path
from importlib import reload

PROJECT_ROOT = Path.cwd().parent.parent  # points to nl-pe/
SRC_PATH = PROJECT_ROOT / "src"
sys.path.insert(0, str(SRC_PATH))  # make nl_pe importable
os.chdir(PROJECT_ROOT)

# %%
import nl_pe.ploting.times as time_plot
reload(time_plot)
from nl_pe.ploting.times import plot_gp_inf_times_bar

# %% [markdown]
# # Exact GPU

# %% [markdown]
# ## CPU vs GPU

# %%
### Batched inf
method_paths = [
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/100000unobs/d1000/b1000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/cpu/fast/1000obs/100000unobs/d1000/b1000",
    "trials/gps/exact/inference_only_speed/batching_study/cpu/fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/cpu/fast/1000obs/100000unobs/d1000/b10000",
]

method_names = [
    "GPU Love, 100k unobs, batch 1k",
    "GPU Love, 100k unobs, batch 10k",
    "GPU Love, 100k unobs, batch 100k",
    "CPU Love, 100k unobs, batch 1k",
    "CPU Love, 100k unobs, batch 10k",
    "CPU Love, 100k unobs, batch 100k",
]


bar_styles = [
        {"color": "blue"},
        {"color": "blue", "hatch": "/"},
        {"color": "blue", "hatch": "///"},
        {"color": "orange"},
        {"color": "orange", "hatch": "/"},
        {"color": "orange", "hatch": "///"},
]

plot_gp_inf_times_bar(
    method_paths=method_paths,
    method_names=method_names,
    styles=bar_styles,
    title="Batching, dim 1000, 1k obs",
    log=False,
)

# %% [markdown]
# ## GPU Batching Study

# %%
### Batched inf
method_paths = [
    "trials/gps/exact/inference_only_speed/batching_study/no_fast/1000obs/100000unobs/d1000/b1000",
    "trials/gps/exact/inference_only_speed/batching_study/no_fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/no_fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/no_fast/1000obs/1000000unobs/d1000/b1000",
    "trials/gps/exact/inference_only_speed/batching_study/no_fast/1000obs/1000000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/no_fast/1000obs/1000000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/100000unobs/d1000/b1000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/100000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/1000000unobs/d1000/b1000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/1000000unobs/d1000/b10000",
    "trials/gps/exact/inference_only_speed/batching_study/fast/1000obs/1000000unobs/d1000/b10000",
]

method_names = [
    "noLove, 100k unobs, batch 1k",
    "noLove, 100k unobs, batch 10k",
    "noLove, 100k unobs, batch 100k",
    "noLove, 1M unobs, batch 1k",
    "noLove, 1M unobs, batch 10k",
    "noLove, 1M unobs, batch 100k",
    "Love, 100k unobs, batch 1k",
    "Love, 100k unobs, batch 10k",
    "Love, 100k unobs, batch 100k",
    "Love, 1M unobs, batch 1k",
    "Love, 1M unobs, batch 10k",
    "Love, 1M unobs, batch 100k",
]


bar_styles = [
        {"color": "blue"},
        {"color": "blue", "hatch": "/"},
        {"color": "blue", "hatch": "///"},
        {"color": "orange"},
        {"color": "orange", "hatch": "/"},
        {"color": "orange", "hatch": "///"},
        {"color": "green"},
        {"color": "green", "hatch": "/"},
        {"color": "green", "hatch": "///"},
        {"color": "red"},
        {"color": "red", "hatch": "/"},
        {"color": "red", "hatch": "///"}
]

plot_gp_inf_times_bar(
    method_paths=method_paths,
    method_names=method_names,
    styles=bar_styles,
    title="Batching, dim 1000, 1k obs",
    log=False,
)

# %%
method_paths = ['trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d10',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d100',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d333',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1000']


method_names = ['d=1', 'd=10', 'd=100', 'd=333', 'd=1000']

bar_styles = [
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},
]

plot_gp_inf_times_bar(
    method_paths=method_paths,
    method_names=method_names,
    styles=bar_styles,
    title="dimensionality, LOVE, 10k unobs, 1k obs",
    log=True,
)

# %% [markdown]
# ### dimensionality, LOVE vs noLOVE
# `n_obs = 1k`
# `n_unobs = 10k`

# %% [markdown]
# #### LOVE

# %%
method_paths = ['trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d10',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d100',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d333',
'trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1000']


method_names = ['d=1', 'd=10', 'd=100', 'd=333', 'd=1000']

bar_styles = [
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},
]

plot_gp_inf_times_bar(
    method_paths=method_paths,
    method_names=method_names,
    styles=bar_styles,
    title="dimensionality, LOVE, 10k unobs, 1k obs",
    log=True,
)

# %%
#back-to-back runs, love vs no love, d1 vs d1000

method_paths = [
    # 1000 obs, 10k unobs
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/dim_study/1000obs/10000unobs/d1000",
    "trials/gps/exact/inference_only_speed/fast/gpu/dim_study/1000obs/10000unobs/d1000",

    # 1000 obs, 100k unobs
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/dim_study/1000obs/100000unobs/d1000",
    "trials/gps/exact/inference_only_speed/fast/gpu/dim_study/1000obs/100000unobs/d1000",

    # 3000 obs, 10k unobs
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/dim_study/3000obs/10000unobs/d1000",
    "trials/gps/exact/inference_only_speed/fast/gpu/dim_study/3000obs/10000unobs/d1000",

    # 3000 obs, 100k unobs
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/dim_study/3000obs/100000unobs/d1000",
    "trials/gps/exact/inference_only_speed/fast/gpu/dim_study/3000obs/100000unobs/d1000",

    # 10000 obs, 10k unobs
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/dim_study/10000obs/10000unobs/d1000",
    "trials/gps/exact/inference_only_speed/fast/gpu/dim_study/10000obs/10000unobs/d1000",

    # 10000 obs, 100k unobs
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/dim_study/10000obs/100000unobs/d1000",
    "trials/gps/exact/inference_only_speed/fast/gpu/dim_study/10000obs/100000unobs/d1000",
]


method_names = [
    "noLOVE 1000obs 10k unobs d1",
    "LOVE 1000obs 10k unobs d1",
    "noLOVE 1000obs 10k unobs d1000",
    "LOVE 1000obs 10k unobs d1000",

    "noLOVE 1000obs 100k unobs d1",
    "LOVE 1000obs 100k unobs d1",
    "noLOVE 1000obs 100k unobs d1000",
    "LOVE 1000obs 100k unobs d1000",

    "noLOVE 3000obs 10k unobs d1",
    "LOVE 3000obs 10k unobs d1",
    "noLOVE 3000obs 10k unobs d1000",
    "LOVE 3000obs 10k unobs d1000",

    "noLOVE 3000obs 100k unobs d1",
    "LOVE 3000obs 100k unobs d1",
    "noLOVE 3000obs 100k unobs d1000",
    "LOVE 3000obs 100k unobs d1000",

    "noLOVE 10000obs 10k unobs d1",
    "LOVE 10000obs 10k unobs d1",
    "noLOVE 10000obs 10k unobs d1000",
    "LOVE 10000obs 10k unobs d1000",

    "noLOVE 10000obs 100k unobs d1",
    "LOVE 10000obs 100k unobs d1",
    "noLOVE 10000obs 100k unobs d1000",
    "LOVE 10000obs 100k unobs d1000",
]


bar_styles = [
    {"color": "red"},                                   # d1 noLOVE
    {"color": "red",  "hatch": "//", "edgecolor": "black"},  # d1 LOVE
    {"color": "blue"},                                  # d1000 noLOVE
    {"color": "blue", "hatch": "//", "edgecolor": "black"}, # d1000 LOVE
] * 6


plot_gp_inf_times_bar(
    method_paths=method_paths,
    method_names=method_names,
    styles=bar_styles,
    title="Back-to-back Runs, Exact GP inference: d=1 vs d=1000 (LOVE vs noLOVE)",
    log=True,
)

# %% [markdown]
# ### LOVE vs not LOVE

# %% [markdown]
# ### Fast (LOVE)

# %%
method_paths = [
    # 10 obs — fast / not_fast
    "trials/gps/exact/inference_only_speed/fast/gpu/10obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10obs/100000unobs/d1",

    # 100 obs
    "trials/gps/exact/inference_only_speed/fast/gpu/100obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/100obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/100obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/100obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/100obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/100obs/100000unobs/d1",

    # 1000 obs
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/100000unobs/d1",

    # 3000 obs
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/100000unobs/d1",

    # 10000 obs
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/100000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/100000unobs/d1",
]


method_names = [
    "fast 10obs 1k unobs d1",      "not_fast 10obs 1k unobs d1",
    "fast 10obs 10k unobs d1",     "not_fast 10obs 10k unobs d1",
    "fast 10obs 100k unobs d1",    "not_fast 10obs 100k unobs d1",

    "fast 100obs 1k unobs d1",     "not_fast 100obs 1k unobs d1",
    "fast 100obs 10k unobs d1",    "not_fast 100obs 10k unobs d1",
    "fast 100obs 100k unobs d1",   "not_fast 100obs 100k unobs d1",

    "fast 1000obs 1k unobs d1",    "not_fast 1000obs 1k unobs d1",
    "fast 1000obs 10k unobs d1",   "not_fast 1000obs 10k unobs d1",
    "fast 1000obs 100k unobs d1",  "not_fast 1000obs 100k unobs d1",

    "fast 3000obs 1k unobs d1",    "not_fast 3000obs 1k unobs d1",
    "fast 3000obs 10k unobs d1",   "not_fast 3000obs 10k unobs d1",
    "fast 3000obs 100k unobs d1",  "not_fast 3000obs 100k unobs d1",

    "fast 10000obs 1k unobs d1",   "not_fast 10000obs 1k unobs d1",
    "fast 10000obs 10k unobs d1",  "not_fast 10000obs 10k unobs d1",
    "fast 10000obs 100k unobs d1", "not_fast 10000obs 100k unobs d1",
]


bar_styles = [
    # 10 obs
    {"color": "blue",   "hatch": "//", "edgecolor": "black"},
    {"color": "blue"},
    {"color": "blue",   "hatch": "//", "edgecolor": "black"},
    {"color": "blue"},
    {"color": "blue",   "hatch": "//", "edgecolor": "black"},
    {"color": "blue"},

    # 100 obs
    {"color": "orange","hatch": "//", "edgecolor": "black"},
    {"color": "orange"},
    {"color": "orange","hatch": "//", "edgecolor": "black"},
    {"color": "orange"},
    {"color": "orange","hatch": "//", "edgecolor": "black"},
    {"color": "orange"},

    # 1000 obs
    {"color": "green", "hatch": "//", "edgecolor": "black"},
    {"color": "green"},
    {"color": "green", "hatch": "//", "edgecolor": "black"},
    {"color": "green"},
    {"color": "green", "hatch": "//", "edgecolor": "black"},
    {"color": "green"},

    # 3000 obs
    {"color": "red",   "hatch": "//", "edgecolor": "black"},
    {"color": "red"},
    {"color": "red",   "hatch": "//", "edgecolor": "black"},
    {"color": "red"},
    {"color": "red",   "hatch": "//", "edgecolor": "black"},
    {"color": "red"},

    # 10000 obs
    {"color": "purple","hatch": "//", "edgecolor": "black"},
    {"color": "purple"},
    {"color": "purple","hatch": "//", "edgecolor": "black"},
    {"color": "purple"},
    {"color": "purple","hatch": "//", "edgecolor": "black"},
    {"color": "purple"},
]


plot_gp_inf_times_bar(
    method_paths=method_paths,
    method_names=method_names,
    styles=bar_styles,
    title="Fast vs non-fast GPU exact GP inference times",
    log=True,
)

# %% [markdown]
# ### analysis
# LOVE is faster when there are >3K observations and/or >10K unobserved points and helps avoid OOM

# %%
method_paths = [
    # n_obs = 10
    "trials/gps/exact/inference_only_speed/fast/gpu/10obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10obs/100000unobs/d1",

    # n_obs = 100
    "trials/gps/exact/inference_only_speed/fast/gpu/100obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/100obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/100obs/100000unobs/d1",

    # n_obs = 1000
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/100000unobs/d1",

    # n_obs = 3000
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/3000obs/100000unobs/d1",

    # n_obs = 10000
    "trials/gps/exact/inference_only_speed/fast/gpu/1000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/fast/gpu/10000obs/100000unobs/d1",

    
]


method_names = [
    # n_obs = 10
    "10obs 1k unobs d1",
    "10obs 10k unobs d1",
    "10obs 100k unobs d1",

    # n_obs = 100
    "100obs 1k unobs d1",
    "100obs 10k unobs d1",
    "100obs 100k unobs d1",

    # n_obs = 1000
    "1000obs 1k unobs d1",
    "1000obs 10k unobs d1",
    "1000obs 100k unobs d1",

    # n_obs = 3000
    "3000obs 1k unobs d1",
    "3000obs 10k unobs d1",
    "3000obs 100k unobs d1",

    # n_obs = 10000
    "10000obs 1k unobs d1",
    "10000obs 10k unobs d1",
    "10000obs 100k unobs d1",

]


bar_styles = [
    # 10 obs
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},

    # 100 obs
    {"color": "orange"},
    {"color": "orange"},
    {"color": "orange"},

    # 1000 obs
    {"color": "green"},
    {"color": "green"},
    {"color": "green"},

    # 3000 obs
    {"color": "red"},
    {"color": "red"},
    {"color": "red"},

    # 1000 obs
    {"color": "purple"},
    {"color": "purple"},
    {"color": "purple"},

]


plot_gp_inf_times_bar(method_paths = method_paths, method_names=method_names, styles=bar_styles,
              title = "Fast GPU exact GP inference times", log = True)

# %% [markdown]
# ### Not LOVE

# %%
method_paths = [
    # n_obs = 10
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10obs/100000unobs/d1",

    # n_obs = 100
    "trials/gps/exact/inference_only_speed/no_fast/gpu/100obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/100obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/100obs/100000unobs/d1",

    # n_obs = 1000
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/100000unobs/d1",

    # n_obs = 3000
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/3000obs/100000unobs/d1",

    # n_obs = 10000
    "trials/gps/exact/inference_only_speed/no_fast/gpu/1000obs/1000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/10000unobs/d1",
    "trials/gps/exact/inference_only_speed/no_fast/gpu/10000obs/100000unobs/d1",
]


method_names = [
    # n_obs = 10
    "10obs 1k unobs d1",
    "10obs 10k unobs d1",
    "10obs 100k unobs d1",

    # n_obs = 100
    "100obs 1k unobs d1",
    "100obs 10k unobs d1",
    "100obs 100k unobs d1",

    # n_obs = 1000
    "1000obs 1k unobs d1",
    "1000obs 10k unobs d1",
    "1000obs 100k unobs d1",

    # n_obs = 3000
    "3000obs 1k unobs d1",
    "3000obs 10k unobs d1",
    "3000obs 100k unobs d1",

    # n_obs = 10000
    "10000obs 1k unobs d1",
    "10000obs 10k unobs d1",
    "10000obs 100k unobs d1",

]


bar_styles = [
    # 10 obs
    {"color": "blue"},
    {"color": "blue"},
    {"color": "blue"},

    # 100 obs
    {"color": "orange"},
    {"color": "orange"},
    {"color": "orange"},

    # 1000 obs
    {"color": "green"},
    {"color": "green"},
    {"color": "green"},

    # 3000 obs
    {"color": "red"},
    {"color": "red"},
    {"color": "red"},

    # 1000 obs
    {"color": "purple"},
    {"color": "purple"},
    {"color": "purple"},

]


plot_gp_inf_times_bar(method_paths = method_paths, method_names=method_names, styles=bar_styles,
              title = "not Fast (not LOVE) GPU exact GP inference times", log = True)
